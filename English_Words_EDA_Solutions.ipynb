# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Sritha-D/EDA_Projects_Pandas/blob/main/English_Words_EDA_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Pandas library

# %%
import pandas as pd

# %% [markdown]
# Read the txt file into a dataframe

# %%
df = pd.read_csv('/content/unix-words.txt')

# %% [markdown]
# Display the first 10 rows of the dataframe

# %%
df.head(10)
# Out:
#           A
# 0         a
# 1        aa
# 2       aal
# 3     aalii
# 4       aam
# 5      Aani
# 6  aardvark
# 7  aardwolf
# 8     Aaron
# 9   Aaronic

# %% [markdown]
# Change the column name 'A' to the words

# %%
df = df.rename(columns = {'A':'Words'})

# %% [markdown]
# Add character count of each word as another column in the dataframe

# %%
df['Words'] = df['Words'].fillna('')
df['CharCount'] = df['Words'].apply(len)

# %% [markdown]
# Add a column called value which is the sum of the numerical positions of the alphabets in the word
# (Ex: aah = 1 + 1 + 8 = 10)

# %%
def summing(word):
  sum = 0
  word.lower()
  for char in word:
    sum += ord(char)-96
  return sum

df['Value'] = df['Words'].apply(summing)
df
# Out:
#              Words  CharCount  Value      Ratio
# 0                a          1      1   1.000000
# 1               aa          2      2   1.000000
# 2              aal          3     14   4.666667
# 3            aalii          5     32   6.400000
# 4              aam          3     15   5.000000
# ...            ...        ...    ...        ...
# 235880      zythem          6     97  16.166667
# 235881      Zythia          6     57   9.500000
# 235882      zythum          6    113  18.833333
# 235883     Zyzomys          7    117  16.714286
# 235884  Zyzzogeton         10    147  14.700000
#
# [235885 rows x 4 columns]

# %% [markdown]
# Write a command to find the number of items in the dataframe

# %%
df.shape
# Out:
# (235885, 3)

# %% [markdown]
# Set the words as the index of the dataframe

# %%
df.set_index('Words')
# Out:
#             CharCount  Value
# Words
# a                   1      1
# aa                  2      2
# aal                 3     14
# aalii               5     32
# aam                 3     15
# ...               ...    ...
# zythem              6     97
# Zythia              6     57
# zythum              6    113
# Zyzomys             7    117
# Zyzzogeton         10    147
#
# [235885 rows x 2 columns]

# %% [markdown]
# What is the value of the word 'Acanthomeridae'?

# %%
df.loc[df['Words'] == 'Acanthomeridae', 'Value']
# Out:
# 762    85
# Name: Value, dtype: int64

# %% [markdown]
# What is the highest possible value for a word?

# %%
df['Value'].max()
# Out:
# 328

# %%
df.max()
# Out:
# Words        zythum
# CharCount        24
# Value           328
# dtype: object

# %% [markdown]
# What is the highest possible length of a word

# %%
df['CharCount'].max()
# Out:
# 24

# %% [markdown]
# What is the name of the word with Value '317'

# %%
df.loc[df['Value'] == 317]
# Out:
#                            Words  CharCount  Value
# 203040  thyroparathyroidectomize         24    317

# %%
df.sort_values(by =['Value'], ascending = False)
# Out:
#                            Words  CharCount  Value      Ratio
# 48117     dacryocystosyringotomy         22    328  14.909091
# 203040  thyroparathyroidectomize         24    317  13.208333
# 225854    ureterocystanastomosis         22    314  14.272727
# 104217    laparocolpohysterotomy         22    307  13.954545
# 160718    pyopneumocholecystitis         22    307  13.954545
# ...                          ...        ...    ...        ...
# 58962                          E          1    -27 -27.000000
# 48066                          D          1    -28 -28.000000
# 14                            Ab          2    -29 -14.500000
# 28165                          C          1    -29 -29.000000
# 17095                          B          1    -30 -30.000000
#
# [235885 rows x 4 columns]

# %% [markdown]
# What is the most common value?

# %%
df['Value'].mode()
# Out:
# 0    102
# Name: Value, dtype: int64

# %%
df['Value'].value_counts().head()
# Out:
# 102    2218
# 107    2194
# 100    2185
# 108    2184
# 115    2171
# Name: Value, dtype: int64

# %% [markdown]
# What is the shortest word with the value of 107

# %%
df.loc[df['Value']==107].min()
# Out:
# Words        Agriochoerus
# CharCount               5
# Value                 107
# dtype: object

# %% [markdown]
# Create a new column 'Ratio' such that ratio = value/char count

# %%
df['Ratio'] = df['Value'] / df['CharCount']

# %%
df
# Out:
#              Words  CharCount  Value      Ratio
# 0                a          1      1   1.000000
# 1               aa          2      2   1.000000
# 2              aal          3     14   4.666667
# 3            aalii          5     32   6.400000
# 4              aam          3     15   5.000000
# ...            ...        ...    ...        ...
# 235880      zythem          6     97  16.166667
# 235881      Zythia          6     57   9.500000
# 235882      zythum          6    113  18.833333
# 235883     Zyzomys          7    117  16.714286
# 235884  Zyzzogeton         10    147  14.700000
#
# [235885 rows x 4 columns]

# %% [markdown]
# What is the maximum value of ratio?

# %%
df['Ratio'].max()
# Out:
# 26.0

# %% [markdown]
# What is the word with the highest ratio

# %%
df.loc[df['Ratio'] == df['Ratio'].max()]
# Out:
#        Words  CharCount  Value  Ratio
# 234937     z          1     26   26.0

# %%
df.sort_values('Ratio', ascending = False)
# Out:
#         Words  CharCount  Value  Ratio
# 234937      z          1     26   26.0
# 234266      y          1     25   25.0
# 233851  wuzzy          5    121   24.2
# 233881      x          1     24   24.0
# 233852     wy          2     48   24.0
# ...       ...        ...    ...    ...
# 48066       D          1    -28  -28.0
# 28165       C          1    -29  -29.0
# 17095       B          1    -30  -30.0
# 122278                 0      0    NaN
# 128519                 0      0    NaN
#
# [235885 rows x 4 columns]

# %% [markdown]
# How many words have the ratio of 10

# %%
df['Ratio'].value_counts()
# Out:
#  12.000000    4334
#  11.000000    4117
#  13.000000    3716
#  10.000000    3159
#  14.000000    2537
#               ...
# -22.000000       1
# -1.272727        1
# -21.000000       1
# -20.000000       1
#  26.000000       1
# Name: Ratio, Length: 1780, dtype: int64

# %%
df.loc[df['Ratio'] == 10]
# Out:
#               Words  CharCount  Value  Ratio
# 7          aardwolf          8     80   10.0
# 31         abaculus          8     80   10.0
# 198        abetment          8     80   10.0
# 329            ably          4     40   10.0
# 403        abounder          8     80   10.0
# ...             ...        ...    ...    ...
# 235406      Zolaist          7     70   10.0
# 235467  zoochemical         11    110   10.0
# 235735     zwieback          8     80   10.0
# 235744    Zygadenus          9     90   10.0
# 235877     Zyrenian          8     80   10.0
#
# [3159 rows x 4 columns]

# %%
df.loc[df['Ratio'] == 10].count()
# Out:
# Words        3159
# CharCount    3159
# Value        3159
# Ratio        3159
# dtype: int64

# %% [markdown]
# What is the maximum value of all words with ratio as 10

# %%
df.loc[df['Ratio'] == 10].max()
# Out:
# Words        zwieback
# CharCount          21
# Value             210
# Ratio            10.0
# dtype: object

# %%
df.query('Ratio == 10').max()
# Out:
# Words        zwieback
# CharCount          21
# Value             210
# Ratio            10.0
# dtype: object

# %% [markdown]
# Of all the words with the value of 260, what has the lowest character count?

# %%
df.query('Value == 260').min()
# Out:
# Words        chromophotolithograph
# CharCount                       17
# Value                          260
# Ratio                    11.818182
# dtype: object

# %%
df.describe()
# Out:
#            CharCount          Value          Ratio
# count  235885.000000  235885.000000  235883.000000
# mean        9.569133     108.969218      11.256517
# std         2.927375      43.525601       2.766208
# min         0.000000     -30.000000     -30.000000
# 25%         8.000000      78.000000       9.846154
# 50%         9.000000     107.000000      11.545455
# 75%        11.000000     137.000000      13.000000
# max        24.000000     328.000000      26.000000
